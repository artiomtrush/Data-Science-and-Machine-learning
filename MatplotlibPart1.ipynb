# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
a = np.linspace(0,5,10)

# %%
b = a ** 3

# %%
a
# Out:
# array([0.        , 0.55555556, 1.11111111, 1.66666667, 2.22222222,
#        2.77777778, 3.33333333, 3.88888889, 4.44444444, 5.        ])

# %%
b
# Out:
# array([  0.        ,   0.17146776,   1.37174211,   4.62962963,
#         10.9739369 ,  21.43347051,  37.03703704,  58.81344307,
#         87.7914952 , 125.        ])

# %%
plt.plot(a,b)

# %%
plt.xlabel('a array')
plt.ylabel('b array')
plt.title('dependence a for b')
# Out:
# Text(0.5, 1.0, 'dependence a for b')

# %%
plt.subplot(1,2,1)
plt.plot(a,b,'r')
plt.subplot(1,2,2)
plt.plot(b,a,'b')

# %%
figure = plt.figure()
axes = figure.add_axes([0.1,0.1,0.8,0.8])
axes.plot(a,b)

# %%
figure1 = plt.figure()
axes1 = figure1.add_axes([0.0,0.0,1,1])
axes2 = figure1.add_axes([0.5,0.5,0.5,0.5])
axes.plot(a,b)

# %%
axes1.set_xlabel('x os')
axes1.set_ylabel('y os')
axes1.set_title('title')
# Out:
# Text(0.5, 1, 'title')

# %%
figure1 = plt.figure()
axes1 = figure1.add_axes([0.0,0.0,1,1])
axes2 = figure1.add_axes([0.5,0.5,0.5,1])
axes.plot(a,b)

# %%
figure1 = plt.figure()
axes1 = figure1.add_axes([0.0,0.0,1,1])
axes1.plot(a,b)
axes1.set_xlabel('x os navernoe')
axes1.set_ylabel('y os navernoe')
axes1.set_title('title  navernoe')
# Out:
# Text(0.5, 1.0, 'title  navernoe')

# %%
figure1 = plt.figure()
axes1 = figure1.add_axes([0.0,0.0,1.0,1.0])
axes2 = figure1.add_axes([0.1,0.4,0.5,0.5])
axes1.plot(a,b,'r')
axes2.plot(b,a,'g')


axes1.set_xlabel('x os navernoe')
axes1.set_ylabel('y os navernoe')
axes1.set_title('title navernoe')
axes2.set_xlabel('x os')
axes2.set_ylabel('y os')
axes2.set_title('title mini')
# Out:
# Text(0.5, 1.0, 'title mini')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
figure, axes = plt.subplots(nrows=2,ncols=4)
plt.tight_layout()
# axes.plot(a,b)

# %%
figure, axes = plt.subplots(nrows=1,ncols=2)
for current_axes in axes:
    current_axes.plot(a,b)

# %%
figure, axes = plt.subplots(nrows=1,ncols=2)
axes[0].plot(a,b)
axes[0].set_xlabel('x0')
axes[0].set_ylabel('y0')
axes[0].set_title('t0')

axes[1].plot(b,a)
axes[1].set_xlabel('x1')
axes[1].set_ylabel('y1')
axes[1].set_title('t1')
# Out:
# Text(0.5, 1.0, 't1')

# %%
figure = plt.figure(figsize=(4,4))
axes = figure.add_axes([0,0,1,1])
axes.plot(a,b)

# %%
figure, axes = plt.subplots(nrows=2, ncols=1,figsize=(7,3))
axes[0].plot(a,b,'r')
axes[1].plot(b,a,'b')

# %%
figure, axes = plt.subplots(nrows=2, ncols=1,figsize=(7,3))
axes[0].plot(a,b,'r')
axes[1].plot(b,a,'b')

plt.tight_layout()

# %%
figure

# %%
figure.savefig('my_fig.png')

# %%
figure = plt.figure()
axes = figure.add_axes([0,0,1,1])
axes.plot(a,b, label='a,b plot')
axes.plot(b,a, label='b,a plot')
axes.legend()

# %%
figure = plt.figure()
axes = figure.add_axes([0,0,1,1])
axes.plot(a,b, label='a,b plot')
axes.plot(b,a, label='b,a plot')
axes.legend(loc=(0.2, 0.6))

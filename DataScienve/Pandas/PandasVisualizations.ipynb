# %%
import numpy as np
import pandas as pd
# %matplotlib inline

# %%
dataFrame1 = pd.read_csv('dataframe1', index_col=0)

# %%
dataFrame1.head()
# Out:
#                    A         B         C         D
# 2019-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2019-01-02 -0.774984  0.157034 -0.882716 -2.253382
# 2019-01-03 -0.921037 -0.482943 -0.419100  0.478638
# 2019-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2019-01-05 -0.905980  1.778576  0.381920  0.291436

# %%
dataFrame2 = pd.read_csv('dataframe2')

# %%
dataFrame2.head()
# Out:
#           a         b         c         d
# 0  0.039262  0.218512  0.103423  0.952904
# 1  0.932283  0.041562  0.899125  0.922630
# 2  0.280504  0.008943  0.552808  0.292510
# 3  0.622212  0.242870  0.264021  0.444353
# 4  0.053829  0.520124  0.552264  0.190003

# %%
dataFrame1['A'].hist()

# %%
dataFrame1['A'].plot.hist()

# %%
dataFrame1['A'].plot.hist(bins=20)

# %%
dataFrame1['A'].plot(kind='hist', bins=20)

# %%
dataFrame2.head()
# Out:
#           a         b         c         d
# 0  0.039262  0.218512  0.103423  0.952904
# 1  0.932283  0.041562  0.899125  0.922630
# 2  0.280504  0.008943  0.552808  0.292510
# 3  0.622212  0.242870  0.264021  0.444353
# 4  0.053829  0.520124  0.552264  0.190003

# %%
dataFrame2.plot.area()

# %%
dataFrame2.plot.area(alpha=0.7)

# %%
dataFrame2.plot.bar()

# %%
dataFrame2.plot.bar(stacked=True)

# %%
dataFrame1['A'].plot.hist()

# %%
dataFrame1.plot.line()

# %%
dataFrame1.plot.line(y='B')

# %%
dataFrame1.plot.line(y='B', figsize=(10,4), lw=3)

# %%
dataFrame1.plot.line(y='B', figsize=(10,4))

# %%
dataFrame1.plot.scatter(x='A', y='B')

# %%
dataFrame1.plot.scatter(x='A', y='B', c='C')

# %%
dataFrame1.plot.scatter(x='A', y='B', c='C', cmap='coolwarm')

# %%
dataFrame1.plot.scatter(x='A', y='B', s=dataFrame1['C']*100)

# %%
dataFrame2.plot.box()

# %%
dataframe = pd.DataFrame(np.random.randn(1000,2), columns=['A','B'])

# %%
dataframe
# Out:
#             A         B
# 0    0.384723  1.726137
# 1   -0.659569  1.660798
# 2   -1.080127 -1.667253
# 3    0.986876 -1.959237
# 4    0.038799 -0.493766
# ..        ...       ...
# 995 -0.010169 -0.944832
# 996 -0.256176 -0.222838
# 997  1.219518  0.446506
# 998 -0.864872 -0.114714
# 999 -0.597052 -0.925473
#
# [1000 rows x 2 columns]

# %%
dataframe.plot.hexbin(x='A', y='B')

# %%
dataframe.plot.hexbin(x='A', y='B', gridsize=30)

# %%
dataframe.plot.hexbin(x='A', y='B', gridsize=30,
                     cmap='coolwarm')
